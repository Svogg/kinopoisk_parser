# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('statistic.csv', encoding='cp1251')

# %%
fig, ax =plt.subplots()
data.plot(kind='bar', x='genre', y='amount', ax=ax)
# Out:
# <AxesSubplot:xlabel='genre'>
